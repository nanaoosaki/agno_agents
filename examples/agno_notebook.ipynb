# %%
from agno.agent import Agent
from agno.models.anthropic import Claude
from agno.tools.reasoning import ReasoningTools
from agno.tools.yfinance import YFinanceTools

# Claude with reasoning tools for complex analysis
reasoning_agent = Agent(
    model=Claude(id="claude-3-7-sonnet-latest"),
    tools=[
        ReasoningTools(
            think=True,
            analyze=True,
            add_instructions=True,
        ),
        YFinanceTools(
            stock_price=True,
            analyst_recommendations=True,
            company_info=True,
        ),
    ],
    instructions="Use structured reasoning for complex problems",
    stream_intermediate_steps=True,
    show_tool_calls=True,
    markdown=True,
)

# %%
# This question will trigger multiple intermediate steps
response_stream = reasoning_agent.run(
    "What is the stock price of NVDA and should I invest in it? "
    "Consider market trends, financial health, and risk factors.",
    stream=True,
    stream_intermediate_steps=True
)

# %%
for event in response_stream:
    if event.event == "RunResponseContent":
        print(f"Content: {event.content}")
    elif event.event == "ToolCallStarted":
        print(f"Tool call started: {event.tool}")
    elif event.event == "ReasoningStep":
        print(f"Reasoning step: {event.content}")
    ...
# Out:
# Content: I'll help you analyze
# Content:  NVDA stock and provide insights
# Content:  on whether it might be a good investment.
# Content:  Let me gather the relevant information for
# Content:  you.
# Content:
# Tool call started: ToolExecution(tool_call_id='toolu_01C1VbMpQQYMXSs3c1tcdegX', tool_name='think', tool_args={'title': 'Planning my approach to analyze NVDA stock', 'thought': 'To provide a comprehensive analysis of NVDA (NVIDIA) as a potential investment, I need to gather several pieces of information:\n1. Current stock price of NVDA using get_current_stock_price\n2. Company information and overview using get_company_info\n3. Analyst recommendations using get_analyst_recommendations\n\nOnce I have this data, I can analyze market trends, financial health, and risk factors to provide an informed perspective on whether NVDA might be a good investment.', 'action': 'Make tool calls to gather the necessary NVDA stock information', 'confidence': 0.95}, tool_call_error=None, result=None, metrics=None, stop_after_tool_call=False, created_at=1755337693, requires_confirmation=None, confirmed=None, confirmation_note=None, requires_user_input=None, user_input_schema=None, answered=None, external_execution_required=None)
# Reasoning step: title='Planning my approach to analyze NVDA stock' action='Make tool calls to gather the necessary NVDA stock information' result=None reasoning='To provide a comprehensive analysis of NVDA (NVIDIA) as a potential investment, I need to gather several pieces of information:\n1. Current stock price of NVDA using get_current_stock_price\n2. Company information and overview using get_company_info\n3. Analyst recommendations using get_analyst_recommendations\n\nOnce I have this data, I can analyze market trends, financial health, and risk factors to provide an informed perspective on whether NVDA might be a good investment.' next_action=<NextAction.CONTINUE: 'continue'> confidence=0.95
# Content:
# Tool call started: ToolExecution(tool_call_id='toolu_01VKf94t2Bybv1cXsW1TRtqv', tool_name='get_current_stock_price', tool_args={'symbol': 'NVDA'}, tool_call_error=None, result=None, metrics=None, stop_after_tool_call=False, created_at=1755337693, requires_confirmation=None, confirmed=None, confirmation_note=None, requires_user_input=None, user_input_schema=None, answered=None, external_execution_required=None)
# Content:
# Tool call started: ToolExecution(tool_call_id='toolu_01TasBH6hTQWGb2PsJq9jFWg', tool_name='get_company_info', tool_args={'symbol': 'NVDA'}, tool_call_error=None, result=None, metrics=None, stop_after_tool_call=False, created_at=1755337693, requires_confirmation=None, confirmed=None, confirmation_note=None, requires_user_input=None, user_input_schema=None, answered=None, external_execution_required=None)
# Content:
# Tool call started: ToolExecution(tool_call_id='toolu_01UgY5ptUbebGYA2Wk4MruTB', tool_name='get_analyst_recommendations', tool_args={'symbol': 'NVDA'}, tool_call_error=None, result=None, metrics=None, stop_after_tool_call=False, created_at=1755337693, requires_confirmation=None, confirmed=None, confirmation_note=None, requires_user_input=None, user_input_schema=None, answered=None, external_execution_required=None)
# Content:
# Tool call started: ToolExecution(tool_call_id='toolu_01JUZqJvQfXECSVSp6BhXqHg', tool_name='analyze', tool_args={'title': 'Analysis of NVDA stock information', 'result': 'Gathered current stock price ($180.45), company information, and analyst recommendations for NVDA', 'analysis': 'I now have comprehensive data on NVIDIA (NVDA) to evaluate it as a potential investment:\n\n1. Current Price and Valuation:\n- Current price: $180.45\n- P/E Ratio: 58.21 (relatively high)\n- Market Cap: $4.4 trillion (extremely large)\n\n2. Financial Health:\n- Strong financial position with $53.69B in cash\n- Impressive free cash flow of $55.44B\n- Operating cash flow of $76.16B\n- EBITDA of $88.25B\n- Excellent gross margins of 70.1%\n- EBITDA margins of 59.42%\n- Revenue growth of 69.2% (exceptional)\n\n3. Market Trends:\n- Trading near its 52-week high of $184.48\n- Well above both 50-day ($163.50) and 200-day ($136.87) moving averages\n- Semiconductor industry is booming, especially with AI demand\n\n4. Analyst Sentiment:\n- Overwhelmingly positive with 11 Strong Buy and 47 Buy ratings\n- Only 6 Hold and 1 Sell ratings\n- Consistent analyst support over past 3 months\n\n5. Risk Factors:\n- High P/E ratio suggests high expectations built into the price\n- Trading near all-time highs\n- Semiconductor industry can be cyclical\n- Intense competition in AI space\n- Regulatory risks around AI\n\nThis information appears complete and I can now provide a comprehensive analysis to the user.', 'next_action': 'final_answer', 'confidence': 0.9}, tool_call_error=None, result=None, metrics=None, stop_after_tool_call=False, created_at=1755337693, requires_confirmation=None, confirmed=None, confirmation_note=None, requires_user_input=None, user_input_schema=None, answered=None, external_execution_required=None)
# Reasoning step: title='Analysis of NVDA stock information' action=None result='Gathered current stock price ($180.45), company information, and analyst recommendations for NVDA' reasoning='I now have comprehensive data on NVIDIA (NVDA) to evaluate it as a potential investment:\n\n1. Current Price and Valuation:\n- Current price: $180.45\n- P/E Ratio: 58.21 (relatively high)\n- Market Cap: $4.4 trillion (extremely large)\n\n2. Financial Health:\n- Strong financial position with $53.69B in cash\n- Impressive free cash flow of $55.44B\n- Operating cash flow of $76.16B\n- EBITDA of $88.25B\n- Excellent gross margins of 70.1%\n- EBITDA margins of 59.42%\n- Revenue growth of 69.2% (exceptional)\n\n3. Market Trends:\n- Trading near its 52-week high of $184.48\n- Well above both 50-day ($163.50) and 200-day ($136.87) moving averages\n- Semiconductor industry is booming, especially with AI demand\n\n4. Analyst Sentiment:\n- Overwhelmingly positive with 11 Strong Buy and 47 Buy ratings\n- Only 6 Hold and 1 Sell ratings\n- Consistent analyst support over past 3 months\n\n5. Risk Factors:\n- High P/E ratio suggests high expectations built into the price\n- Trading near all-time highs\n- Semiconductor industry can be cyclical\n- Intense competition in AI space\n- Regulatory risks around AI\n\nThis information appears complete and I can now provide a comprehensive analysis to the user.' next_action=<NextAction.FINAL_ANSWER: 'final_answer'> confidence=0.9
# Content: #
# Content:  NVIDIA (NVDA
# Content: ) Stock Analysis
#
# ## Current
# Content:  Stock Information
# - **Current Price**: $180
# Content: .45
# - **52
# Content: -Week Range**: $86
# Content: .62 - $184.
# Content: 48
# - **Market Cap**: $4.
# Content: 4 trillion
#
# ## Investment
# Content:  Analysis
#
# ### Strengths
# - **
# Content: Exceptional Financial Performance**:
# Content:
#   - 69.2% revenue
# Content:  growth
#   - $53
# Content: .69B in cash reserves
# Content:
#   - Strong free cash flow of $55
# Content: .44B
#   -
# Content:  Excellent gross margins of
# Content: 70.1%
#
# - **Market Position**
# Content: :
#   - Leading position
# Content:  in AI and graphics processing
#   -
# Content:  Dominant player in data center GPU market
#
# Content: - Well-positioned in emerging
# Content:  technologies (autonomous vehicles, robotics)
# Content:
#
# - **Analyst Confidence
# Content: **:
#   -
# Content:  Overwhelming analyst support with 58
# Content:  positive recommendations (11 Strong Buy,
# Content:  47 Buy)
#   - Only
# Content: 7 neutral or negative ratings (6
# Content: Hold, 1
# Content: Sell)
#
# ### Risk
# Content:  Factors
# - **Valuation
# Content:  Concerns**:
#
# Content: - P/E ratio of
# Content: 58.21 is relatively high
#   -
# Content:  Trading near its 52-week high
# Content:
#   - High expectations built into the current
# Content:  price
#
# - **Industry Risks**:
# Content:
#   - Semiconductor industry can be cyclical
# Content:
#   - Intense competition in the
# Content:  AI chip space
#   - Potential
# Content:  regulatory challenges related to AI technology
# Content:
#
# ## Investment Recommendation
# Content:
#
# NVIDIA presents a compelling investment case
# Content:  based on its financial strength, market position,
# Content:  and analyst sentiment. The
# Content:  company is at the forefront of AI
# Content:  and computational technologies with exceptional
# Content:  growth and profitability metrics
# Content: .
#
# However, the current
# Content:  valuation requires careful consideration. With
# Content:  a high P/E ratio an
# Content: d trading near all-time highs, much
# Content:  of the anticipated growth may already be priced in
# Content: .
#
# **Recommendation approach
# Content: **:
# - **
# Content: Long-term investors**: Consider establishing
# Content:  or maintaining a position,
# Content:  potentially through dollar-cost averaging
# -
# Content:  **Short-term investors**: Exercise
# Content:  caution due to val
# Content: uation and potential market volatility
# Content:
# - **Risk-averse investors**:
# Content:  Consider waiting for a more attractive entry point or
# Content:  taking a smaller position
# Content:
#
# As with any investment, consider how
# Content:  NVIDIA fits within your overall portfolio
# Content:  diversification, investment timeline, and risk tolerance
# Content: . Consulting with a financial advisor for
# Content:  personalized advice is recommended.
# Content:
